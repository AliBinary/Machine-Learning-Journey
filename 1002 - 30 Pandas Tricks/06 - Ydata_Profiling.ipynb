# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Pandas Trick 06</h1>
#     <h3 align="center">YData Profiling (formerly Pandas Profiling)</h3>
#     <h4 align="center"><a href="https://github.com/AliBinary">Ali Ghanbari</a></h5>
# </div>

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd

# %%
pd.__version__

# %% [markdown]
# ## Import Dataset & Make Dataframe

# %%
df = pd.read_csv('./Data/titanic.csv')
df.head()

# %% [markdown]
# ## Ydata Profiling

# %%
# !pip uninstall -y pandas-profiling

# %%
# !pip install -U ydata-profiling

# %%
from ydata_profiling import ProfileReport
import ydata_profiling

ydata_profiling.__version__

# %%
profile = ProfileReport(df)

# Use minimal=True for faster report generation on large datasets
# profile = ProfileReport(df, minimal=True)

# profile

# %%
profile.to_file("ydata-profiling_report.html")

# %%
import webbrowser
webbrowser.open("ydata-profiling_report.html")
