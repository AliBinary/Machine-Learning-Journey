# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Pandas Trick 14</h1>
#     <h3 align="center">How to Filter Dataframe based on Categories</h3>
#     <h4 align="center"><a href="https://github.com/AliBinary">Ali Ghanbari</a></h5>
# </div>

# %% [markdown]
# ### Importing the libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
pd.__version__

# %% [markdown]
# ## Import Dataset and Make Dataframe

# %%
df=pd.read_csv('Churn_Modelling.csv')
df.sample()

# %%
df.Geography.unique()

# %%
df.Geography.value_counts()

# %%
df[(df.Geography == 'France') | (df.Geography == 'Spain')].head()

# %%
df[df.Geography.isin(['France', 'Spain'])].head()

# %%
df[~df.Geography.isin(['France', 'Spain'])].head()
