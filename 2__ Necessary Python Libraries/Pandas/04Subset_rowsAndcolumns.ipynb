# %%
import pandas as pd

# %%
# fa_cols = ['تاریخ',
#  'کیلومتر کارکرد',
#  'شماره شاسی',
#  'سازنده',
#  'Model',
#  'Type',
#  'قیمت بازار',
#  'قیمت کارخانه',
#  'توضیحات']
# en_cols = ['Date',
#  'Milage',
#  'VIN',
#  'Made',
#  'Model',
#  'Type',
#  'Price',
#  'Order',
#  'Explain']

# cols_dict= dict(zip(fa_cols , en_cols))

# %%
# df = pd.read_excel('./Data/Cars_data.xlsx')

# %%
# df.rename(columns = cols_dict).reset_index().to_excel("./Data/CarsENCols.xlsx", index=False)

df= pd.read_excel("./Data/CarsENCols.xlsx" , index_col = 0 )

# %%
df.head(2)

# %%
# df.iloc[0:10]

df.iloc[: , [1, 2, 6]]

# %%
df.head(2)

# %%
# df.loc[: , "Date":"Made"]


df.loc[df['Milage']> 35000, ["Date" , "Price"]]

# %% [markdown]
# # Access a Cell
# ### iat
# ### at

# %%
df.head()

# %%
df.iat[1 , 2]
df.iat[4 , 6]

# %%
df.at[4 , "VIN"]

# %%
# df.iat[4 , "VIN"]
