# %%
import pandas as pd

df = pd.read_excel("./Data/CleanData.xlsx")

# %%
df.head()

# %%
gb = df.groupby("Model")

# %%
gb

# %%
for name , group in gb :
    print(name)
    print("______")
    print(group)
    print(30*"$")

# %%
df.head()

# %%
df = df.set_index("Date")

# %%
df.index

# %%
gb2 = df.groupby(level="Date")

# %%
for i in gb2 :
    print(i)

# %%
gb.size()

# %%
gb2.size()

# %%
gb.agg('count')

# %%
def count_plus100(thing):
    return len(thing) + 100

# %%
gb.agg(count_plus100)

# %%
for name , group in gb:
    print(name)
    print(group)
    print(group.shift(10))

# %%
gb3 = df.groupby('Order')

# %%
for name , group in gb3:
    # print(group)
    # print(30*'_')
    print(group["Order"].cumsum())
    print(30*'$')
