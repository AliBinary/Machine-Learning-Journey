# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('./Data/CleanData.xlsx')

# %%
df.head(2)
# Out:
#    index        Date  Milage                 VIN   Made  Model       Type  \
# 0      0  1400-1-تیر   24393  NA0000000000000200  سایپا  پراید  Hatchback
# 1      1  1400-2-تیر   18177  NA0000000000000201  سایپا  پراید  Hatchback
#
#       Price     Order Explain
# 0  17049382  17000000  بی رنگ
# 1  20059011  17000000   بیرنگ

# %%
df.shape
# Out:
# (184, 10)

# %%
rahvar_data = df.sample(n = 7)

# %%
rahvar_data['Accident'] = np.random.choice(['Moghaser' , "____" , "50%"] , 7)

# %%
rahvar_data.reset_index(inplace = True)

# %%
rahvar_data = rahvar_data[["VIN" , "Accident"]]

# %%
rahvar_data.to_excel("./Data/RahvarData.xlsx" , index = None)

# %%
rahvar_data2 = pd.read_excel("./Data/RahvarData.xlsx")

# %%
rahvar_data2.shape
# Out:
# (7, 2)

# %%
rahvar_data2.loc[len(rahvar_data2)] = ['NT9999000000000200' , "Moghaser"]

# %%
rahvar_data2
# Out:
#                   VIN  Accident
# 0  NA0000000000000203      ____
# 1  NA0000000000000263       50%
# 2  NA0000000000000372  Moghaser
# 3  NA0000000000000373       50%
# 4  NA0000000000000223      ____
# 5  NA0000000000000309      ____
# 6  NA0000000000000303      ____
# 7  NT9999000000000200  Moghaser

# %%
left_merge = pd.merge(df , rahvar_data2 , how = 'left')

# %%
left_merge
# Out:
#      index           Date  Milage                 VIN        Made   Model  \
# 0        0     1400-1-تیر   24393  NA0000000000000200       سایپا   پراید
# 1        1     1400-2-تیر   18177  NA0000000000000201       سایپا   پراید
# 2        2     1400-3-تیر   20600  NA0000000000000202       سایپا   پراید
# 3        3     1400-4-تیر   26210  NA0000000000000203       سایپا   پراید
# 4        4     1400-5-تیر   24213  NA0000000000000204       سایپا   پراید
# ..     ...            ...     ...                 ...         ...     ...
# 179    192   1400-7-مرداد   20468  NA0000000000000392  ایرانخودرو  پژو206
# 180    193   1400-8-مرداد   20747  NA0000000000000393  ایرانخودرو  پژو206
# 181    194   1400-9-مرداد   20397  NA0000000000000394  ایرانخودرو  پژو206
# 182    195  1400-10-مرداد   24358  NA0000000000000395  ایرانخودرو  پژو206
# 183    196  1400-11-مرداد   27363  NA0000000000000396  ایرانخودرو  پژو206
#
#           Type     Price     Order     Explain Accident
# 0    Hatchback  17049382  17000000      بی رنگ      NaN
# 1    Hatchback  20059011  17000000       بیرنگ      NaN
# 2    Hatchback  17085239  17000000        زدگی      NaN
# 3    Hatchback  19220924  17000000       تصادف     ____
# 4    Hatchback  20566626  17000000  بدون تصادف      NaN
# ..         ...       ...       ...         ...      ...
# 179      Sedan  27423787  21000000        زدگی      NaN
# 180      Sedan  25184712  21000000       تصادف      NaN
# 181      Sedan  23437833  21000000  بدون تصادف      NaN
# 182      Sedan  29411805  21000000      فابریک      NaN
# 183      Sedan  25025798  21000000      بی رنگ      NaN
#
# [184 rows x 11 columns]

# %%
right_merge = pd.merge(df , rahvar_data2 , how = 'right' , on = "VIN")

# %%
right_merge
# Out:
#    index            Date   Milage                 VIN        Made   Model  \
# 0    3.0      1400-4-تیر  26210.0  NA0000000000000203       سایپا   پراید
# 1   63.0   1400-2-شهریور  21192.0  NA0000000000000263  ایرانخودرو  پژو206
# 2  172.0  1400-18-شهریور  28513.0  NA0000000000000372  ایرانخودرو  پژو206
# 3  173.0  1400-19-شهریور  17391.0  NA0000000000000373  ایرانخودرو  پژو206
# 4   23.0     1400-24-تیر  27392.0  NA0000000000000223  ایرانخودرو  پژو206
# 5  109.0     1400-17-تیر  18728.0  NA0000000000000309  ایرانخودرو  پژو206
# 6  103.0     1400-11-تیر  20593.0  NA0000000000000303  ایرانخودرو  پژو206
# 7    NaN             NaN      NaN  NT9999000000000200         NaN     NaN
#
#         Type       Price       Order     Explain  Accident
# 0  Hatchback  19220924.0  17000000.0       تصادف      ____
# 1      Sedan  23087383.0  21000000.0  بدون تصادف       50%
# 2  Hatchback  27117654.0  22000000.0  بدون تصادف  Moghaser
# 3  Hatchback  25906747.0  22000000.0      فابریک       50%
# 4  Hatchback  25401548.0  20000000.0      فابریک      ____
# 5  Hatchback  24056175.0  22000000.0      بی رنگ      ____
# 6  Hatchback  24974600.0  22000000.0      بی رنگ      ____
# 7        NaN         NaN         NaN         NaN  Moghaser

# %%
inner_merge = pd.merge(df , rahvar_data2 , how = 'inner' )

# %%
inner_merge
# Out:
#    index            Date  Milage                 VIN        Made   Model  \
# 0      3      1400-4-تیر   26210  NA0000000000000203       سایپا   پراید
# 1     23     1400-24-تیر   27392  NA0000000000000223  ایرانخودرو  پژو206
# 2     63   1400-2-شهریور   21192  NA0000000000000263  ایرانخودرو  پژو206
# 3    103     1400-11-تیر   20593  NA0000000000000303  ایرانخودرو  پژو206
# 4    109     1400-17-تیر   18728  NA0000000000000309  ایرانخودرو  پژو206
# 5    172  1400-18-شهریور   28513  NA0000000000000372  ایرانخودرو  پژو206
# 6    173  1400-19-شهریور   17391  NA0000000000000373  ایرانخودرو  پژو206
#
#         Type     Price     Order     Explain  Accident
# 0  Hatchback  19220924  17000000       تصادف      ____
# 1  Hatchback  25401548  20000000      فابریک      ____
# 2      Sedan  23087383  21000000  بدون تصادف       50%
# 3  Hatchback  24974600  22000000      بی رنگ      ____
# 4  Hatchback  24056175  22000000      بی رنگ      ____
# 5  Hatchback  27117654  22000000  بدون تصادف  Moghaser
# 6  Hatchback  25906747  22000000      فابریک       50%

# %%
inner_merge2 = pd.merge(df , rahvar_data2  )

# %%
inner_merge2
# Out:
#    index            Date  Milage                 VIN        Made   Model  \
# 0      3      1400-4-تیر   26210  NA0000000000000203       سایپا   پراید
# 1     23     1400-24-تیر   27392  NA0000000000000223  ایرانخودرو  پژو206
# 2     63   1400-2-شهریور   21192  NA0000000000000263  ایرانخودرو  پژو206
# 3    103     1400-11-تیر   20593  NA0000000000000303  ایرانخودرو  پژو206
# 4    109     1400-17-تیر   18728  NA0000000000000309  ایرانخودرو  پژو206
# 5    172  1400-18-شهریور   28513  NA0000000000000372  ایرانخودرو  پژو206
# 6    173  1400-19-شهریور   17391  NA0000000000000373  ایرانخودرو  پژو206
#
#         Type     Price     Order     Explain  Accident
# 0  Hatchback  19220924  17000000       تصادف      ____
# 1  Hatchback  25401548  20000000      فابریک      ____
# 2      Sedan  23087383  21000000  بدون تصادف       50%
# 3  Hatchback  24974600  22000000      بی رنگ      ____
# 4  Hatchback  24056175  22000000      بی رنگ      ____
# 5  Hatchback  27117654  22000000  بدون تصادف  Moghaser
# 6  Hatchback  25906747  22000000      فابریک       50%

# %%
outer_merge2 = pd.merge(df , rahvar_data2   , how = "outer")

# %%
outer_merge2
# Out:
#      index           Date   Milage                 VIN        Made   Model  \
# 0      0.0     1400-1-تیر  24393.0  NA0000000000000200       سایپا   پراید
# 1      1.0     1400-2-تیر  18177.0  NA0000000000000201       سایپا   پراید
# 2      2.0     1400-3-تیر  20600.0  NA0000000000000202       سایپا   پراید
# 3      3.0     1400-4-تیر  26210.0  NA0000000000000203       سایپا   پراید
# 4      4.0     1400-5-تیر  24213.0  NA0000000000000204       سایپا   پراید
# ..     ...            ...      ...                 ...         ...     ...
# 180  193.0   1400-8-مرداد  20747.0  NA0000000000000393  ایرانخودرو  پژو206
# 181  194.0   1400-9-مرداد  20397.0  NA0000000000000394  ایرانخودرو  پژو206
# 182  195.0  1400-10-مرداد  24358.0  NA0000000000000395  ایرانخودرو  پژو206
# 183  196.0  1400-11-مرداد  27363.0  NA0000000000000396  ایرانخودرو  پژو206
# 184    NaN            NaN      NaN  NT9999000000000200         NaN     NaN
#
#           Type       Price       Order     Explain  Accident
# 0    Hatchback  17049382.0  17000000.0      بی رنگ       NaN
# 1    Hatchback  20059011.0  17000000.0       بیرنگ       NaN
# 2    Hatchback  17085239.0  17000000.0        زدگی       NaN
# 3    Hatchback  19220924.0  17000000.0       تصادف      ____
# 4    Hatchback  20566626.0  17000000.0  بدون تصادف       NaN
# ..         ...         ...         ...         ...       ...
# 180      Sedan  25184712.0  21000000.0       تصادف       NaN
# 181      Sedan  23437833.0  21000000.0  بدون تصادف       NaN
# 182      Sedan  29411805.0  21000000.0      فابریک       NaN
# 183      Sedan  25025798.0  21000000.0      بی رنگ       NaN
# 184        NaN         NaN         NaN         NaN  Moghaser
#
# [185 rows x 11 columns]

# %% [markdown]
# # Filtering Data

# %%
df[~df['VIN'].isin(rahvar_data2['VIN'])]
# Out:
#      index           Date  Milage                 VIN        Made   Model  \
# 0        0     1400-1-تیر   24393  NA0000000000000200       سایپا   پراید
# 1        1     1400-2-تیر   18177  NA0000000000000201       سایپا   پراید
# 2        2     1400-3-تیر   20600  NA0000000000000202       سایپا   پراید
# 4        4     1400-5-تیر   24213  NA0000000000000204       سایپا   پراید
# 5        5     1400-6-تیر   24628  NA0000000000000205       سایپا   پراید
# ..     ...            ...     ...                 ...         ...     ...
# 179    192   1400-7-مرداد   20468  NA0000000000000392  ایرانخودرو  پژو206
# 180    193   1400-8-مرداد   20747  NA0000000000000393  ایرانخودرو  پژو206
# 181    194   1400-9-مرداد   20397  NA0000000000000394  ایرانخودرو  پژو206
# 182    195  1400-10-مرداد   24358  NA0000000000000395  ایرانخودرو  پژو206
# 183    196  1400-11-مرداد   27363  NA0000000000000396  ایرانخودرو  پژو206
#
#           Type     Price     Order     Explain
# 0    Hatchback  17049382  17000000      بی رنگ
# 1    Hatchback  20059011  17000000       بیرنگ
# 2    Hatchback  17085239  17000000        زدگی
# 4    Hatchback  20566626  17000000  بدون تصادف
# 5    Hatchback  17586869  17000000      فابریک
# ..         ...       ...       ...         ...
# 179      Sedan  27423787  21000000        زدگی
# 180      Sedan  25184712  21000000       تصادف
# 181      Sedan  23437833  21000000  بدون تصادف
# 182      Sedan  29411805  21000000      فابریک
# 183      Sedan  25025798  21000000      بی رنگ
#
# [177 rows x 10 columns]
