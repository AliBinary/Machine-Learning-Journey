# %%
# !pip install mitosheet

# %%
import mitosheet

# %%
mitosheet.sheet(analysis_to_replay="id-kaylgpipui")

# %%
from mitosheet import *; register_analysis("id-kaylgpipui");
    
# Imported final.csv
import pandas as pd
final = pd.read_csv(r'final.csv')

# Changed رتبه در منطقه to dtype int
final['رتبه در منطقه'] = final['رتبه در منطقه'].fillna(0).astype('int')

# Added column new-column-78sk
final.insert(4, 'new-column-78sk', 0)

# Added column new-column-7yx2
final.insert(4, 'new-column-7yx2', 0)

# Deleted columns new-column-78sk
final.drop(['new-column-78sk'], axis=1, inplace=True)

# Renamed columns رتبه در منطقه در تعداد آزمون
final.rename(columns={'new-column-7yx2': 'رتبه در منطقه در تعداد آزمون'}, inplace=True)

# Set formula of رتبه در منطقه در تعداد آزمون
final['رتبه در منطقه در تعداد آزمون'] = final['رتبه در منطقه']*final['تعداد آزمون']

# Changed تعداد آزمون to dtype int
final['تعداد آزمون'] = final['تعداد آزمون'].fillna(0).astype('int')

# Changed رتبه در منطقه در تعداد آزمون to dtype int
final['رتبه در منطقه در تعداد آزمون'] = final['رتبه در منطقه در تعداد آزمون'].fillna(0).astype('int')

# %%
from mitosheet import *; register_analysis("id-kgniyixlgw");
    
# Imported final.csv
import pandas as pd
final = pd.read_csv(r'final.csv')

# Changed رتبه در منطقه to dtype int
final['رتبه در منطقه'] = final['رتبه در منطقه'].fillna(0).astype('int')

# Renamed columns منطق
final.rename(columns={'منطقه': 'منطق'}, inplace=True)

# %%
from mitosheet import *; register_analysis("id-jbnzidchpj");
    
# Imported final.csv
import pandas as pd
final = pd.read_csv(r'final.csv')

# Filtered شهر
final = final[final['شهر'].str.contains('تهران', na=False)]

# Changed تعداد آزمون to dtype int
final['تعداد آزمون'] = final['تعداد آزمون'].fillna(0).astype('int')

# Renamed columns سال قبولی
final.rename(columns={'سال': 'سال قبولی'}, inplace=True)

# Added column new-column-1v8g
final.insert(3, 'new-column-1v8g', 0)

# Renamed columns تست
final.rename(columns={'new-column-1v8g': 'تست'}, inplace=True)

# Set formula of تست
final['تست'] = SUM(final['رتبه کشوری'],final['رتبه در منطقه'])

# Changed تست to dtype int
final['تست'] = final['تست'].fillna(0).astype('int')
